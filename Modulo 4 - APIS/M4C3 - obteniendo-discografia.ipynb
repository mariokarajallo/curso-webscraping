# %%
import requests

# %%
#guardamos el id de la pagina del artista en spotify en este ejemplo coldplay
id_artist='4gzpq5DPGxSnKTe4SA8HAU'

# %%
url_base='https://api.spotify.com/v1'

# %%
#ENDPOINT para artistas
ep_artist='/artists/{id}'

# %%
#juntamos nuestra URL final
url_artist=url_base+ep_artist.format(id=id_artist)

# %%
#creamos nuestra peticion
r_spotify=requests.get(url_artist)

# %%
#vemos el estado que no desvuelte la peticion
r_spotify.status_code
# Out:
# 401

# %%
#utilizamos este metodo para visualizar lo que devuelve el JSON de nuestro peticion
r_spotify.json()
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %%
token_url='https://accounts.spotify.com/api/token'

# %%
params={'grant_type':'client_credentials'}

# %%
headers={'Authorization':'Basic MDI5NTI4OTQzNWMyNDc2Yjk2YWVhYTYzNTk1ODQzZjQ6NTBlYzcwMmY1YjkxNDIxMDhmNzNiNzE1MjA4NGNjNWM='}

# %%
r = requests.post(token_url, data=params, headers=headers )

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'access_token': 'BQA5mEgrn9HnA0gk3_uLJpRvU-g8dRm2BrjDRTBxdeQD-G45E-jq5nX_79OiVIik9vEGF1Kn_FEfF1vsveH1aqpiiIAohCk_CRpkU85M39lm93Wr8zE',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
token = r.json()['access_token']
token
# Out:
# 'BQA5mEgrn9HnA0gk3_uLJpRvU-g8dRm2BrjDRTBxdeQD-G45E-jq5nX_79OiVIik9vEGF1Kn_FEfF1vsveH1aqpiiIAohCk_CRpkU85M39lm93Wr8zE'

# %%
header = {"Authorization":"Bearer {}".format(token)}

# %%
r = requests.get(url_artist, headers=header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#  'followers': {'href': None, 'total': 39878148},
#  'genres': ['permanent wave', 'pop'],
#  'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#  'id': '4gzpq5DPGxSnKTe4SA8HAU',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb989ed05e1f0570cc4726c2d3',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174989ed05e1f0570cc4726c2d3',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178989ed05e1f0570cc4726c2d3',
#    'width': 160}],
#  'name': 'Coldplay',
#  'popularity': 88,
#  'type': 'artist',
#  'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}

# %% [markdown]
# ### Busqueda artista

# %%
url_busqueda='https://api.spotify.com/v1/search'

# %%
search_params={'q': 'coldplay', 'type':'artist'}

# %%
r_busqueda=requests.get(url_busqueda,headers=header,params=search_params)

# %%
r_busqueda.status_code
# Out:
# 200

# %%
r_busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=coldplay&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'followers': {'href': None, 'total': 39878148},
#     'genres': ['permanent wave', 'pop'],
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb989ed05e1f0570cc4726c2d3',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174989ed05e1f0570cc4726c2d3',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178989ed05e1f0570cc4726c2d3',
#       'width': 160}],
#     'name': 'Coldplay',
#     'popularity': 88,
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4vo52leFHFB2QIw12xQywP'},
#     'followers': {'href': None, 'total': 1},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4vo52leFHFB2QIw12xQywP',
#     'id': '4vo52leFHFB2QIw12xQywP',
#     'images': [],
#     'name': 'coldoutlay',
#     'popularity': 16,
#     'type': 'artist',
#     'uri': 'spotify:artist:4vo52leFHFB2QIw12xQywP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/14cDx3yNMNO94Ghqo3kVoF'},
#     'followers': {'href': None, 'total': 231},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/14cDx3yNMNO94Ghqo3kVoF',
#     'id': '14cDx3yNMNO94Ghqo3kVoF',
#     'images': [],
#     'name': 'Coldplay & Lele',
#     'popularity': 4,
#     'type': 'artist',
#     'uri': 'spotify:artist:14cDx3yNMNO94Ghqo3kVoF'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#     'followers': {'href': None, 'total': 14541940},
#     'genres': ['piano rock', 'pop'],
#     'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#     'id': '5Pwc4xIPtQLFEnJriah9YJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb77bf00f67e21f514dc44c485',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517477bf00f67e21f514dc44c485',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17877bf00f67e21f514dc44c485',
#       'width': 160}],
#     'name': 'OneRepublic',
#     'popularity': 83,
#     'type': 'artist',
#     'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5xLV9zlHfEcyhvT9KJpch7'},
#     'followers': {'href': None, 'total': 20},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5xLV9zlHfEcyhvT9KJpch7',
#     'id': '5xLV9zlHfEcyhvT9KJpch7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27372919545d5e4c2ad5d578097',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0272919545d5e4c2ad5d578097',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485172919545d5e4c2ad5d578097',
#       'width': 64}],
#     'name': 'Coldlay',
#     'popularity': 6,
#     'type': 'artist',
#     'uri': 'spotify:artist:5xLV9zlHfEcyhvT9KJpch7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rug1v8OwBTLKCFbkyGiVl'},
#     'followers': {'href': None, 'total': 2},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4rug1v8OwBTLKCFbkyGiVl',
#     'id': '4rug1v8OwBTLKCFbkyGiVl',
#     'images': [],
#     'name': 'ColdPlay Wu',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:4rug1v8OwBTLKCFbkyGiVl'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/54wN2dOk1qcTsURH43DgjA'},
#     'followers': {'href': None, 'total': 9},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/54wN2dOk1qcTsURH43DgjA',
#     'id': '54wN2dOk1qcTsURH43DgjA',
#     'images': [],
#     'name': 'ColdPlayTae',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:54wN2dOk1qcTsURH43DgjA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#     'followers': {'href': None, 'total': 19657932},
#     'genres': ['dance pop',
#      'edm',
#      'electropop',
#      'pop',
#      'pop dance',
#      'tropical house'],
#     'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#     'id': '69GGBxA162lTqCwzJG5jLp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb3c02f4fb4cc9187c488afd50',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051743c02f4fb4cc9187c488afd50',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1783c02f4fb4cc9187c488afd50',
#       'width': 160}],
#     'name': 'The Chainsmokers',
#     'popularity': 79,
#     'type': 'artist',
#     'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Fw5hnHXdVGmHxRm7wNJu5'},
#     'followers': {'href': None, 'total': 1},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2Fw5hnHXdVGmHxRm7wNJu5',
#     'id': '2Fw5hnHXdVGmHxRm7wNJu5',
#     'images': [],
#     'name': 'coldoutlay',
#     'popularity': 6,
#     'type': 'artist',
#     'uri': 'spotify:artist:2Fw5hnHXdVGmHxRm7wNJu5'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/163PshEvNd3i3RdxHXGTii'},
#     'followers': {'href': None, 'total': 95},
#     'genres': ['classify'],
#     'href': 'https://api.spotify.com/v1/artists/163PshEvNd3i3RdxHXGTii',
#     'id': '163PshEvNd3i3RdxHXGTii',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb62152cb1cd2424a992024a71',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517462152cb1cd2424a992024a71',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17862152cb1cd2424a992024a71',
#       'width': 160}],
#     'name': 'Playa Piano',
#     'popularity': 37,
#     'type': 'artist',
#     'uri': 'spotify:artist:163PshEvNd3i3RdxHXGTii'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2H9LqfZIYlJmpK9lfT8Q4W'},
#     'followers': {'href': None, 'total': 281},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2H9LqfZIYlJmpK9lfT8Q4W',
#     'id': '2H9LqfZIYlJmpK9lfT8Q4W',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb9c4d3f3c64d39a69ee038879',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051749c4d3f3c64d39a69ee038879',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1789c4d3f3c64d39a69ee038879',
#       'width': 160}],
#     'name': 'Cold Piece',
#     'popularity': 6,
#     'type': 'artist',
#     'uri': 'spotify:artist:2H9LqfZIYlJmpK9lfT8Q4W'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wKgCt0edHo68HTsrWEJb2'},
#     'followers': {'href': None, 'total': 386},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2wKgCt0edHo68HTsrWEJb2',
#     'id': '2wKgCt0edHo68HTsrWEJb2',
#     'images': [],
#     'name': 'Karaoke - Coldplay',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:2wKgCt0edHo68HTsrWEJb2'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4IQ3LhwLnc7Fhl8WYmq0NY'},
#     'followers': {'href': None, 'total': 88},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4IQ3LhwLnc7Fhl8WYmq0NY',
#     'id': '4IQ3LhwLnc7Fhl8WYmq0NY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273da14ab711891a37122c160ee',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02da14ab711891a37122c160ee',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851da14ab711891a37122c160ee',
#       'width': 64}],
#     'name': 'The Scientists',
#     'popularity': 29,
#     'type': 'artist',
#     'uri': 'spotify:artist:4IQ3LhwLnc7Fhl8WYmq0NY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3h03Zll7KezpPPFPcKFXZY'},
#     'followers': {'href': None, 'total': 1548},
#     'genres': ['popgaze'],
#     'href': 'https://api.spotify.com/v1/artists/3h03Zll7KezpPPFPcKFXZY',
#     'id': '3h03Zll7KezpPPFPcKFXZY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebcaa9f04d4e5e31c71ef95807',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174caa9f04d4e5e31c71ef95807',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178caa9f04d4e5e31c71ef95807',
#       'width': 160}],
#     'name': 'Cold Pumas',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:3h03Zll7KezpPPFPcKFXZY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ztMJAoRFWrN0B0mM880Gl'},
#     'followers': {'href': None, 'total': 562},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1ztMJAoRFWrN0B0mM880Gl',
#     'id': '1ztMJAoRFWrN0B0mM880Gl',
#     'images': [],
#     'name': 'Coldplay Metal Tribute',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:1ztMJAoRFWrN0B0mM880Gl'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ilUB3NMw5oU1jMmnrUkF7'},
#     'followers': {'href': None, 'total': 8},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1ilUB3NMw5oU1jMmnrUkF7',
#     'id': '1ilUB3NMw5oU1jMmnrUkF7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27392c41e27dd5ba6c2dbe3df17',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0292c41e27dd5ba6c2dbe3df17',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485192c41e27dd5ba6c2dbe3df17',
#       'width': 64}],
#     'name': 'My Fantastic',
#     'popularity': 22,
#     'type': 'artist',
#     'uri': 'spotify:artist:1ilUB3NMw5oU1jMmnrUkF7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0H9heaou8RFqjiz9Yhcznx'},
#     'followers': {'href': None, 'total': 146},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0H9heaou8RFqjiz9Yhcznx',
#     'id': '0H9heaou8RFqjiz9Yhcznx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e95ec38c3401543ca6e46e21',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e95ec38c3401543ca6e46e21',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e95ec38c3401543ca6e46e21',
#       'width': 64}],
#     'name': 'Coldpast',
#     'popularity': 4,
#     'type': 'artist',
#     'uri': 'spotify:artist:0H9heaou8RFqjiz9Yhcznx'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0WHCs1nv58vHXWrb3AdmOw'},
#     'followers': {'href': None, 'total': 161},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0WHCs1nv58vHXWrb3AdmOw',
#     'id': '0WHCs1nv58vHXWrb3AdmOw',
#     'images': [],
#     'name': 'Coldplay, Base Karaoke + Choirs',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:0WHCs1nv58vHXWrb3AdmOw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6MERXsiRbur2oJZFgYRDKz'},
#     'followers': {'href': None, 'total': 641934},
#     'genres': ['bow pop'],
#     'href': 'https://api.spotify.com/v1/artists/6MERXsiRbur2oJZFgYRDKz',
#     'id': '6MERXsiRbur2oJZFgYRDKz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb15ea9aa08b96f51e3bacf0cd',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517415ea9aa08b96f51e3bacf0cd',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17815ea9aa08b96f51e3bacf0cd',
#       'width': 160}],
#     'name': 'Vitamin String Quartet',
#     'popularity': 61,
#     'type': 'artist',
#     'uri': 'spotify:artist:6MERXsiRbur2oJZFgYRDKz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/25gCdy3nBno9fUfqYQZc7b'},
#     'followers': {'href': None, 'total': 69},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/25gCdy3nBno9fUfqYQZc7b',
#     'id': '25gCdy3nBno9fUfqYQZc7b',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebfde3dcbb4fb665158b723a3a',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174fde3dcbb4fb665158b723a3a',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178fde3dcbb4fb665158b723a3a',
#       'width': 160}],
#     'name': 'coldblock',
#     'popularity': 10,
#     'type': 'artist',
#     'uri': 'spotify:artist:25gCdy3nBno9fUfqYQZc7b'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=coldplay&type=artist&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 36}}

# %% [markdown]
# En la respuesta tenemos los artitas que encontro bajo 'artist' como una lisata en 'items'

# %%
import pandas as pd

# %%
df = pd.DataFrame(r_busqueda.json()['artists']['items'])
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/4...
# 1  {'spotify': 'https://open.spotify.com/artist/4...
# 2  {'spotify': 'https://open.spotify.com/artist/1...
# 3  {'spotify': 'https://open.spotify.com/artist/5...
# 4  {'spotify': 'https://open.spotify.com/artist/5...
#
#                            followers                 genres  \
# 0  {'href': None, 'total': 39878148}  [permanent wave, pop]
# 1         {'href': None, 'total': 1}                     []
# 2       {'href': None, 'total': 231}                     []
# 3  {'href': None, 'total': 14541940}      [piano rock, pop]
# 4        {'href': None, 'total': 20}                     []
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/4gzpq5DPGxS...  4gzpq5DPGxSnKTe4SA8HAU
# 1  https://api.spotify.com/v1/artists/4vo52leFHFB...  4vo52leFHFB2QIw12xQywP
# 2  https://api.spotify.com/v1/artists/14cDx3yNMNO...  14cDx3yNMNO94Ghqo3kVoF
# 3  https://api.spotify.com/v1/artists/5Pwc4xIPtQL...  5Pwc4xIPtQLFEnJriah9YJ
# 4  https://api.spotify.com/v1/artists/5xLV9zlHfEc...  5xLV9zlHfEcyhvT9KJpch7
#
#                                               images             name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...         Coldplay
# 1                                                 []       coldoutlay
# 2                                                 []  Coldplay & Lele
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...      OneRepublic
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...          Coldlay
#
#    popularity    type                                    uri
# 0          88  artist  spotify:artist:4gzpq5DPGxSnKTe4SA8HAU
# 1          16  artist  spotify:artist:4vo52leFHFB2QIw12xQywP
# 2           4  artist  spotify:artist:14cDx3yNMNO94Ghqo3kVoF
# 3          83  artist  spotify:artist:5Pwc4xIPtQLFEnJriah9YJ
# 4           6  artist  spotify:artist:5xLV9zlHfEcyhvT9KJpch7

# %% [markdown]
# 1. Ordenamos el df por popularidad
# 2. quedarse con la primera fila
# 3. quedarse con la columna id

# %%
df.sort_values(by='popularity', ascending=False).iloc[0]['id']
# Out:
# '4gzpq5DPGxSnKTe4SA8HAU'

# %% [markdown]
# ### Obteniendo Discografia

# %%
import base64

# %%
def get_token(client_id, client_secret):
    encoded = base64.b64encode(bytes(client_id+':'+client_secret, 'utf-8'))
    params = {'grant_type':'client_credentials'}
    header={'Authorization': 'Basic ' + str(encoded, 'utf-8')}
    r_token= requests.post('https://accounts.spotify.com/api/token', headers=header, data=params)
    if r_token.status_code != 200:
        print('Error en la request.', r_token.json())
        return None
    print('Token válido por {} segundos.'.format(r_token.json()['expires_in']))
    return r_token.json()['access_token']

# %%
client_id='0295289435c2476b96aeaa63595843f4'
client_secret= '50ec702f5b9142108f73b7152084cc5c'
token=get_token(client_id, client_secret)
# Out:
# Token válido por 3600 segundos.

# %%
header={'Authorization':'Bearer {}'.format(token)}

# %%
id_artist
# Out:
# '4gzpq5DPGxSnKTe4SA8HAU'

# %%
r_artist= requests.get(url_artist, headers=header )
r_artist.status_code
# Out:
# 200

# %%
r_artist.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#  'followers': {'href': None, 'total': 39878148},
#  'genres': ['permanent wave', 'pop'],
#  'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#  'id': '4gzpq5DPGxSnKTe4SA8HAU',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb989ed05e1f0570cc4726c2d3',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174989ed05e1f0570cc4726c2d3',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178989ed05e1f0570cc4726c2d3',
#    'width': 160}],
#  'name': 'Coldplay',
#  'popularity': 88,
#  'type': 'artist',
#  'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}

# %%
params={'country': 'AR'}

# %%
album_artist=requests.get(url_artist+'/albums', headers=header, params=params)
album_artist.status_code
# Out:
# 200

# %%
album_artist.json()['items']
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/06mXfvDsRZNfnsGZvX2zpb'},
#   'href': 'https://api.spotify.com/v1/albums/06mXfvDsRZNfnsGZvX2zpb',
#   'id': '06mXfvDsRZNfnsGZvX2zpb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273ec10f247b100da1ce0d80b6d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02ec10f247b100da1ce0d80b6d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851ec10f247b100da1ce0d80b6d',
#     'width': 64}],
#   'name': 'Music Of The Spheres',
#   'release_date': '2021-10-15',
#   'release_date_precision': 'day',
#   'total_tracks': 12,
#   'type': 'album',
#   'uri': 'spotify:album:06mXfvDsRZNfnsGZvX2zpb'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2FeyIYDDAQqcOJKOKhvHdr'},
#   'href': 'https://api.spotify.com/v1/albums/2FeyIYDDAQqcOJKOKhvHdr',
#   'id': '2FeyIYDDAQqcOJKOKhvHdr',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273733913465adb99353020b805',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02733913465adb99353020b805',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851733913465adb99353020b805',
#     'width': 64}],
#   'name': 'Everyday Life',
#   'release_date': '2019-11-22',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:2FeyIYDDAQqcOJKOKhvHdr'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4dBp8rzdqH9unSndGk6g6o'},
#   'href': 'https://api.spotify.com/v1/albums/4dBp8rzdqH9unSndGk6g6o',
#   'id': '4dBp8rzdqH9unSndGk6g6o',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737409e3398d17262a3ad6e58b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027409e3398d17262a3ad6e58b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517409e3398d17262a3ad6e58b',
#     'width': 64}],
#   'name': 'Everyday Life',
#   'release_date': '2019-11-22',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:4dBp8rzdqH9unSndGk6g6o'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/19CvkGjYpifkdwgVJSbog2'},
#   'href': 'https://api.spotify.com/v1/albums/19CvkGjYpifkdwgVJSbog2',
#   'id': '19CvkGjYpifkdwgVJSbog2',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fe5f1f4d742869a253036971',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fe5f1f4d742869a253036971',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fe5f1f4d742869a253036971',
#     'width': 64}],
#   'name': 'Live in Buenos Aires',
#   'release_date': '2018-12-07',
#   'release_date_precision': 'day',
#   'total_tracks': 24,
#   'type': 'album',
#   'uri': 'spotify:album:19CvkGjYpifkdwgVJSbog2'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3cfAM8b8KqJRoIzt3zLKqw'},
#   'href': 'https://api.spotify.com/v1/albums/3cfAM8b8KqJRoIzt3zLKqw',
#   'id': '3cfAM8b8KqJRoIzt3zLKqw',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738ff7c3580d429c8212b9a3b6',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028ff7c3580d429c8212b9a3b6',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518ff7c3580d429c8212b9a3b6',
#     'width': 64}],
#   'name': 'A Head Full of Dreams',
#   'release_date': '2015-12-04',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:3cfAM8b8KqJRoIzt3zLKqw'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1hNS0RsxPTFjmKXCgmjSLS'},
#   'href': 'https://api.spotify.com/v1/albums/1hNS0RsxPTFjmKXCgmjSLS',
#   'id': '1hNS0RsxPTFjmKXCgmjSLS',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e17c11c195f80da123e17dde',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e17c11c195f80da123e17dde',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e17c11c195f80da123e17dde',
#     'width': 64}],
#   'name': 'Ghost Stories Live 2014',
#   'release_date': '2014-11-21',
#   'release_date_precision': 'day',
#   'total_tracks': 9,
#   'type': 'album',
#   'uri': 'spotify:album:1hNS0RsxPTFjmKXCgmjSLS'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2G4AUqfwxcV1UdQjm2ouYr'},
#   'href': 'https://api.spotify.com/v1/albums/2G4AUqfwxcV1UdQjm2ouYr',
#   'id': '2G4AUqfwxcV1UdQjm2ouYr',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f864bcdcc245f06831d17ae0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f864bcdcc245f06831d17ae0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f864bcdcc245f06831d17ae0',
#     'width': 64}],
#   'name': 'Ghost Stories',
#   'release_date': '2014-05-19',
#   'release_date_precision': 'day',
#   'total_tracks': 9,
#   'type': 'album',
#   'uri': 'spotify:album:2G4AUqfwxcV1UdQjm2ouYr'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2OkEsqGTfu8PWRrNHzfr0m'},
#   'href': 'https://api.spotify.com/v1/albums/2OkEsqGTfu8PWRrNHzfr0m',
#   'id': '2OkEsqGTfu8PWRrNHzfr0m',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730e49a9823be8f295caf1a574',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020e49a9823be8f295caf1a574',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510e49a9823be8f295caf1a574',
#     'width': 64}],
#   'name': 'Live 2012',
#   'release_date': '2012-11-19',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:2OkEsqGTfu8PWRrNHzfr0m'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2R7iJz5uaHjLEVnMkloO18'},
#   'href': 'https://api.spotify.com/v1/albums/2R7iJz5uaHjLEVnMkloO18',
#   'id': '2R7iJz5uaHjLEVnMkloO18',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273de0cd11d7b31c3bd1fd5983d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02de0cd11d7b31c3bd1fd5983d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851de0cd11d7b31c3bd1fd5983d',
#     'width': 64}],
#   'name': 'Mylo Xyloto',
#   'release_date': '2011-10-24',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'type': 'album',
#   'uri': 'spotify:album:2R7iJz5uaHjLEVnMkloO18'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3pboBm7GTa6V5dFXXCt52b'},
#   'href': 'https://api.spotify.com/v1/albums/3pboBm7GTa6V5dFXXCt52b',
#   'id': '3pboBm7GTa6V5dFXXCt52b',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739ef50b3c2d29efe1172925c6',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029ef50b3c2d29efe1172925c6',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519ef50b3c2d29efe1172925c6',
#     'width': 64}],
#   'name': 'LeftRightLeftRightLeft (Live)',
#   'release_date': '2009-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 9,
#   'type': 'album',
#   'uri': 'spotify:album:3pboBm7GTa6V5dFXXCt52b'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/71pRFAwHBLrjKYRG7V1Q2o'},
#   'href': 'https://api.spotify.com/v1/albums/71pRFAwHBLrjKYRG7V1Q2o',
#   'id': '71pRFAwHBLrjKYRG7V1Q2o',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273121b47fdc79958a05e67fb17',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02121b47fdc79958a05e67fb17',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851121b47fdc79958a05e67fb17',
#     'width': 64}],
#   'name': "Viva La Vida (Prospekt's March Edition)",
#   'release_date': '2008-11-24',
#   'release_date_precision': 'day',
#   'total_tracks': 18,
#   'type': 'album',
#   'uri': 'spotify:album:71pRFAwHBLrjKYRG7V1Q2o'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2LIlrvVO0NP48jamVdlDo3'},
#   'href': 'https://api.spotify.com/v1/albums/2LIlrvVO0NP48jamVdlDo3',
#   'id': '2LIlrvVO0NP48jamVdlDo3',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2732b8f3df886a655baa8c137c9',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e022b8f3df886a655baa8c137c9',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048512b8f3df886a655baa8c137c9',
#     'width': 64}],
#   'name': "Viva La Vida (Prospekt's March Edition)",
#   'release_date': '2008-11-24',
#   'release_date_precision': 'day',
#   'total_tracks': 18,
#   'type': 'album',
#   'uri': 'spotify:album:2LIlrvVO0NP48jamVdlDo3'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1CEODgTmTwLyabvwd7HBty'},
#   'href': 'https://api.spotify.com/v1/albums/1CEODgTmTwLyabvwd7HBty',
#   'id': '1CEODgTmTwLyabvwd7HBty',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e21cc1db05580b6f2d2a3b6e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e21cc1db05580b6f2d2a3b6e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e21cc1db05580b6f2d2a3b6e',
#     'width': 64}],
#   'name': 'Viva La Vida or Death and All His Friends',
#   'release_date': '2008-05-26',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:1CEODgTmTwLyabvwd7HBty'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4E7bV0pzG0LciBSWTszra6'},
#   'href': 'https://api.spotify.com/v1/albums/4E7bV0pzG0LciBSWTszra6',
#   'id': '4E7bV0pzG0LciBSWTszra6',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2734e0362c225863f6ae2432651',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e024e0362c225863f6ae2432651',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048514e0362c225863f6ae2432651',
#     'width': 64}],
#   'name': 'X&Y',
#   'release_date': '2005-06-07',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:4E7bV0pzG0LciBSWTszra6'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3JMOZD2qixTTLRW9I6JuF4'},
#   'href': 'https://api.spotify.com/v1/albums/3JMOZD2qixTTLRW9I6JuF4',
#   'id': '3JMOZD2qixTTLRW9I6JuF4',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27323969e14b74349ffcf79f55e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0223969e14b74349ffcf79f55e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485123969e14b74349ffcf79f55e',
#     'width': 64}],
#   'name': 'Live 2003',
#   'release_date': '2003-11-01',
#   'release_date_precision': 'day',
#   'total_tracks': 12,
#   'type': 'album',
#   'uri': 'spotify:album:3JMOZD2qixTTLRW9I6JuF4'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0RHX9XECH8IVI3LNgWDpmQ'},
#   'href': 'https://api.spotify.com/v1/albums/0RHX9XECH8IVI3LNgWDpmQ',
#   'id': '0RHX9XECH8IVI3LNgWDpmQ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273de09e02aa7febf30b7c02d82',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02de09e02aa7febf30b7c02d82',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851de09e02aa7febf30b7c02d82',
#     'width': 64}],
#   'name': 'A Rush of Blood to the Head',
#   'release_date': '2002-08-08',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:0RHX9XECH8IVI3LNgWDpmQ'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'},
#   'href': 'https://api.spotify.com/v1/albums/6ZG5lRT77aJ3btmArcykra',
#   'id': '6ZG5lRT77aJ3btmArcykra',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733d92b2ad5af9fbc8637425f0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023d92b2ad5af9fbc8637425f0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513d92b2ad5af9fbc8637425f0',
#     'width': 64}],
#   'name': 'Parachutes',
#   'release_date': '2000-07-10',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:6ZG5lRT77aJ3btmArcykra'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/574iaZA34RiT9rM1F2s2IM'},
#   'href': 'https://api.spotify.com/v1/albums/574iaZA34RiT9rM1F2s2IM',
#   'id': '574iaZA34RiT9rM1F2s2IM',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273289ac619a0993bbe19484727',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02289ac619a0993bbe19484727',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851289ac619a0993bbe19484727',
#     'width': 64}],
#   'name': 'Biutyful',
#   'release_date': '2022-07-06',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:574iaZA34RiT9rM1F2s2IM'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#     'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#     'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#     'name': 'Selena Gomez',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4AKwRarlmsUlLjIwt38NLw'},
#     'href': 'https://api.spotify.com/v1/artists/4AKwRarlmsUlLjIwt38NLw',
#     'id': '4AKwRarlmsUlLjIwt38NLw',
#     'name': 'Ofenbach',
#     'type': 'artist',
#     'uri': 'spotify:artist:4AKwRarlmsUlLjIwt38NLw'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7lbSZjlBsWuXtR3WqsdOSN'},
#   'href': 'https://api.spotify.com/v1/albums/7lbSZjlBsWuXtR3WqsdOSN',
#   'id': '7lbSZjlBsWuXtR3WqsdOSN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c1872d02df5bf96ffb8ef81c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c1872d02df5bf96ffb8ef81c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c1872d02df5bf96ffb8ef81c',
#     'width': 64}],
#   'name': 'Let Somebody Go (Ofenbach Remix)',
#   'release_date': '2022-04-15',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:7lbSZjlBsWuXtR3WqsdOSN'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#     'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#     'id': '4gzpq5DPGxSnKTe4SA8HAU',
#     'name': 'Coldplay',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#     'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#     'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#     'name': 'Selena Gomez',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1mbwiDXEr8l6mK7o76dqyu'},
#   'href': 'https://api.spotify.com/v1/albums/1mbwiDXEr8l6mK7o76dqyu',
#   'id': '1mbwiDXEr8l6mK7o76dqyu',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730e40385d4f6875e628ca95a2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020e40385d4f6875e628ca95a2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510e40385d4f6875e628ca95a2',
#     'width': 64}],
#   'name': 'Let Somebody Go (Piano Version)',
#   'release_date': '2022-03-18',
#   'release_date_precision': 'day',
#   'total_tracks': 4,
#   'type': 'album',
#   'uri': 'spotify:album:1mbwiDXEr8l6mK7o76dqyu'}]

# %%
[]
