# %%
import requests

# %%
#guardamos el id de la pagina del artista en spotify en este ejemplo BadBunny
id_artist='4q3ewBCX7sLwd24euuV69X'

# %%
url_base='https://api.spotify.com/v1'

# %%
#ENDPOINT para artistas
ep_artist='/artists/{id}'

# %%
#juntamos nuestra URL final
url_artist=url_base+ep_artist.format(id=id_artist)

# %%
url_artist
# Out:
# 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'

# %%
#creamos nuestra peticion
r_spotify=requests.get(url_artist)

# %%
#vemos el estado que no desvuelte la peticion
r_spotify.status_code
# Out:
# 401

# %%
#utilizamos este metodo para visualizar lo que devuelve el JSON de nuestro peticion
r_spotify.json()
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %%
token_url='https://accounts.spotify.com/api/token'

# %%
params={'grant_type':'client_credentials'}

# %%
headers={'Authorization':'Basic MDI5NT5453KPf2I4OTQzNWMyNDc2Yjk2YWVhYTYzNTk1ODQzZjQ6NTBlYzcwMmY1YjkxNDIxMDhmNzNiNzE1MjA4NGNjNWM='}

# %%
r = requests.post(token_url, data=params, headers=headers )

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'access_token': 'BQALZw_xACX-zQPKXOthUoq1-ZJeuikc5VdAkDbdIrLN7l4wtsmP4bXR-mjma04ayZKyn66zkzPEqrX3IJhASl0nu9wUJH8ieNp9PWy-G1vJ7XpcqCs',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
token = r.json()['access_token']
token
# Out:
# 'BQALZw_xACX-zQPKXOthUoq1-ZJeuikc5VdAkDbdIrLN7l4wtsmP4bXR-mjma04ayZKyn66zkzPEqrX3IJhASl0nu9wUJH8ieNp9PWy-G1vJ7XpcqCs'

# %%
header = {"Authorization":"Bearer {}".format(token)}

# %%
r = requests.get(url_artist, headers=header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  'followers': {'href': None, 'total': 62921570},
#  'genres': ['reggaeton', 'trap latino', 'urbano latino'],
#  'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#  'id': '4q3ewBCX7sLwd24euuV69X',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb8ee9a6f54dcbd4bc95126b14',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051748ee9a6f54dcbd4bc95126b14',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1788ee9a6f54dcbd4bc95126b14',
#    'width': 160}],
#  'name': 'Bad Bunny',
#  'popularity': 100,
#  'type': 'artist',
#  'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}

# %% [markdown]
# ### Busqueda artista

# %%
url_busqueda='https://api.spotify.com/v1/search'

# %%
search_params={'q': 'bad bunny', 'type':'artist'}

# %%
r_busqueda=requests.get(url_busqueda,headers=header,params=search_params)

# %%
r_busqueda.status_code
# Out:
# 200

# %%
r_busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=bad+bunny&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'followers': {'href': None, 'total': 62921570},
#     'genres': ['reggaeton', 'trap latino', 'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb8ee9a6f54dcbd4bc95126b14',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051748ee9a6f54dcbd4bc95126b14',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1788ee9a6f54dcbd4bc95126b14',
#       'width': 160}],
#     'name': 'Bad Bunny',
#     'popularity': 100,
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3JAKWLBL9jZ5Ad3KWc04eU'},
#     'followers': {'href': None, 'total': 21},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3JAKWLBL9jZ5Ad3KWc04eU',
#     'id': '3JAKWLBL9jZ5Ad3KWc04eU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738e8593d7a760cf5351d4760c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028e8593d7a760cf5351d4760c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518e8593d7a760cf5351d4760c',
#       'width': 64}],
#     'name': 'Bad Bunny Zombie',
#     'popularity': 4,
#     'type': 'artist',
#     'uri': 'spotify:artist:3JAKWLBL9jZ5Ad3KWc04eU'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1vyhD5VmyZ7KMfW5gqLgo5'},
#     'followers': {'href': None, 'total': 36356300},
#     'genres': ['reggaeton', 'reggaeton colombiano', 'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/1vyhD5VmyZ7KMfW5gqLgo5',
#     'id': '1vyhD5VmyZ7KMfW5gqLgo5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb5d0fc400392250a750a9403e',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051745d0fc400392250a750a9403e',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1785d0fc400392250a750a9403e',
#       'width': 160}],
#     'name': 'J Balvin',
#     'popularity': 88,
#     'type': 'artist',
#     'uri': 'spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3LSkCPMcNIbOscoVhky6ce'},
#     'followers': {'href': None, 'total': 775},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3LSkCPMcNIbOscoVhky6ce',
#     'id': '3LSkCPMcNIbOscoVhky6ce',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a67e59947fd59246c5ff3a8e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a67e59947fd59246c5ff3a8e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a67e59947fd59246c5ff3a8e',
#       'width': 64}],
#     'name': 'Bad Bunny Trap',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:3LSkCPMcNIbOscoVhky6ce'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1y3Ebk2jgtnSj9WyWsDhQi'},
#     'followers': {'href': None, 'total': 26},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1y3Ebk2jgtnSj9WyWsDhQi',
#     'id': '1y3Ebk2jgtnSj9WyWsDhQi',
#     'images': [],
#     'name': 'Bad Pepa Bunny',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:1y3Ebk2jgtnSj9WyWsDhQi'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#     'followers': {'href': None, 'total': 9602766},
#     'genres': ['latin hip hop', 'reggaeton', 'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#     'id': '4SsVbpTthjScTS7U2hmr1X',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebe963e7ad5259c34a7ca54319',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174e963e7ad5259c34a7ca54319',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178e963e7ad5259c34a7ca54319',
#       'width': 160}],
#     'name': 'Arcángel',
#     'popularity': 87,
#     'type': 'artist',
#     'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3dJzwISoDyeRgflMly1EcE'},
#     'followers': {'href': None, 'total': 5584},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3dJzwISoDyeRgflMly1EcE',
#     'id': '3dJzwISoDyeRgflMly1EcE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb1a19321f66bc0272cfc8d38d',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051741a19321f66bc0272cfc8d38d',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1781a19321f66bc0272cfc8d38d',
#       'width': 160}],
#     'name': 'Dead Bad Bunny',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:3dJzwISoDyeRgflMly1EcE'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/18Cgc3wh2bCEW8HzEz3db3'},
#     'followers': {'href': None, 'total': 19687},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/18Cgc3wh2bCEW8HzEz3db3',
#     'id': '18Cgc3wh2bCEW8HzEz3db3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eba071deb3558498a6ae70f15e',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174a071deb3558498a6ae70f15e',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178a071deb3558498a6ae70f15e',
#       'width': 160}],
#     'name': 'Lil Baby Grand',
#     'popularity': 41,
#     'type': 'artist',
#     'uri': 'spotify:artist:18Cgc3wh2bCEW8HzEz3db3'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1KfgiTqlxf9h5ncnlL6vzt'},
#     'followers': {'href': None, 'total': 379},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1KfgiTqlxf9h5ncnlL6vzt',
#     'id': '1KfgiTqlxf9h5ncnlL6vzt',
#     'images': [],
#     'name': 'Cardi B - Bad Bunny',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:1KfgiTqlxf9h5ncnlL6vzt'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1LCD5lfYd2aP1GtX1VJc3X'},
#     'followers': {'href': None, 'total': 3},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1LCD5lfYd2aP1GtX1VJc3X',
#     'id': '1LCD5lfYd2aP1GtX1VJc3X',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733449fb99a26b47c8fadf5925',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023449fb99a26b47c8fadf5925',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513449fb99a26b47c8fadf5925',
#       'width': 64}],
#     'name': 'bunny baaby bad',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:1LCD5lfYd2aP1GtX1VJc3X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/12vb80Km0Ew53ABfJOepVz'},
#     'followers': {'href': None, 'total': 4040782},
#     'genres': ['latin hip hop',
#      'reggaeton',
#      'reggaeton flow',
#      'trap latino',
#      'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/12vb80Km0Ew53ABfJOepVz',
#     'id': '12vb80Km0Ew53ABfJOepVz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb88b99535ed74688cf963d8c8',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517488b99535ed74688cf963d8c8',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17888b99535ed74688cf963d8c8',
#       'width': 160}],
#     'name': 'Ñengo Flow',
#     'popularity': 84,
#     'type': 'artist',
#     'uri': 'spotify:artist:12vb80Km0Ew53ABfJOepVz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0thiRBGoXU2kENAMaBL8dP'},
#     'followers': {'href': None, 'total': 72},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0thiRBGoXU2kENAMaBL8dP',
#     'id': '0thiRBGoXU2kENAMaBL8dP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731228f3e4eb5bf12c0aa7a640',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021228f3e4eb5bf12c0aa7a640',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511228f3e4eb5bf12c0aa7a640',
#       'width': 64}],
#     'name': 'Mr Bad Bunny',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:0thiRBGoXU2kENAMaBL8dP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6nVcHLIgY5pE2YCl8ubca1'},
#     'followers': {'href': None, 'total': 557849},
#     'genres': ['reggaeton', 'trap latino', 'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/6nVcHLIgY5pE2YCl8ubca1',
#     'id': '6nVcHLIgY5pE2YCl8ubca1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb05fb1367376b79b86ee0f96c',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517405fb1367376b79b86ee0f96c',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17805fb1367376b79b86ee0f96c',
#       'width': 160}],
#     'name': 'Jhayco',
#     'popularity': 84,
#     'type': 'artist',
#     'uri': 'spotify:artist:6nVcHLIgY5pE2YCl8ubca1'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5hdhHgpxyniooUiQVaPxQ0'},
#     'followers': {'href': None, 'total': 4228596},
#     'genres': ['latin hip hop', 'reggaeton', 'trap latino', 'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/5hdhHgpxyniooUiQVaPxQ0',
#     'id': '5hdhHgpxyniooUiQVaPxQ0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebf6c0e106b139be41baae72fd',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174f6c0e106b139be41baae72fd',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178f6c0e106b139be41baae72fd',
#       'width': 160}],
#     'name': 'Nio Garcia',
#     'popularity': 74,
#     'type': 'artist',
#     'uri': 'spotify:artist:5hdhHgpxyniooUiQVaPxQ0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#     'followers': {'href': None, 'total': 31033024},
#     'genres': ['latin hip hop', 'reggaeton', 'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#     'id': '4VMYDCV2IEDYJArk749S6m',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb302f3eba0a1b9364a1c63204',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174302f3eba0a1b9364a1c63204',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178302f3eba0a1b9364a1c63204',
#       'width': 160}],
#     'name': 'Daddy Yankee',
#     'popularity': 88,
#     'type': 'artist',
#     'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0GM7qgcRCORpGnfcN2tCiB'},
#     'followers': {'href': None, 'total': 1171612},
#     'genres': ['latin hip hop',
#      'latin pop',
#      'pop reggaeton',
#      'reggaeton',
#      'reggaeton flow',
#      'trap latino',
#      'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/0GM7qgcRCORpGnfcN2tCiB',
#     'id': '0GM7qgcRCORpGnfcN2tCiB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb72453ad016b059b06fd52569',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517472453ad016b059b06fd52569',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17872453ad016b059b06fd52569',
#       'width': 160}],
#     'name': 'Tainy',
#     'popularity': 78,
#     'type': 'artist',
#     'uri': 'spotify:artist:0GM7qgcRCORpGnfcN2tCiB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#     'followers': {'href': None, 'total': 31446368},
#     'genres': ['reggaeton', 'reggaeton colombiano', 'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#     'id': '790FomKkXshlbRYZFtlgla',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb0403f4e5b7cb258665d2ed3d',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051740403f4e5b7cb258665d2ed3d',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1780403f4e5b7cb258665d2ed3d',
#       'width': 160}],
#     'name': 'KAROL G',
#     'popularity': 87,
#     'type': 'artist',
#     'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1i8SpTcr7yvPOmcqrbnVXY'},
#     'followers': {'href': None, 'total': 35149875},
#     'genres': ['puerto rican pop',
#      'reggaeton',
#      'trap latino',
#      'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/1i8SpTcr7yvPOmcqrbnVXY',
#     'id': '1i8SpTcr7yvPOmcqrbnVXY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb39ce949d62ff47fc1de1a2d9',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517439ce949d62ff47fc1de1a2d9',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17839ce949d62ff47fc1de1a2d9',
#       'width': 160}],
#     'name': 'Ozuna',
#     'popularity': 90,
#     'type': 'artist',
#     'uri': 'spotify:artist:1i8SpTcr7yvPOmcqrbnVXY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'},
#     'followers': {'href': None, 'total': 26206453},
#     'genres': ['reggaeton',
#      'reggaeton flow',
#      'trap boricua',
#      'trap latino',
#      'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66',
#     'id': '2R21vXR83lH98kGeO99Y66',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebfea27ddf11b9df5322a13c84',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174fea27ddf11b9df5322a13c84',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178fea27ddf11b9df5322a13c84',
#       'width': 160}],
#     'name': 'Anuel AA',
#     'popularity': 89,
#     'type': 'artist',
#     'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mcTU81TzQhprhouKaTkpq'},
#     'followers': {'href': None, 'total': 15193014},
#     'genres': ['puerto rican pop', 'trap latino', 'urbano latino'],
#     'href': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq',
#     'id': '1mcTU81TzQhprhouKaTkpq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb923e85a0eefbab49fd8d4920',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174923e85a0eefbab49fd8d4920',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178923e85a0eefbab49fd8d4920',
#       'width': 160}],
#     'name': 'Rauw Alejandro',
#     'popularity': 91,
#     'type': 'artist',
#     'uri': 'spotify:artist:1mcTU81TzQhprhouKaTkpq'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=bad+bunny&type=artist&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 27}}

# %% [markdown]
# En la respuesta tenemos los artitas que encontro bajo 'artist' como una lista en 'items'

# %%
import pandas as pd

# %%
df = pd.DataFrame(r_busqueda.json()['artists']['items'])
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/4...
# 1  {'spotify': 'https://open.spotify.com/artist/3...
# 2  {'spotify': 'https://open.spotify.com/artist/1...
# 3  {'spotify': 'https://open.spotify.com/artist/3...
# 4  {'spotify': 'https://open.spotify.com/artist/1...
#
#                            followers  \
# 0  {'href': None, 'total': 62921570}
# 1        {'href': None, 'total': 21}
# 2  {'href': None, 'total': 36356300}
# 3       {'href': None, 'total': 775}
# 4        {'href': None, 'total': 26}
#
#                                              genres  \
# 0           [reggaeton, trap latino, urbano latino]
# 1                                                []
# 2  [reggaeton, reggaeton colombiano, urbano latino]
# 3                                                []
# 4                                                []
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/4q3ewBCX7sL...  4q3ewBCX7sLwd24euuV69X
# 1  https://api.spotify.com/v1/artists/3JAKWLBL9jZ...  3JAKWLBL9jZ5Ad3KWc04eU
# 2  https://api.spotify.com/v1/artists/1vyhD5VmyZ7...  1vyhD5VmyZ7KMfW5gqLgo5
# 3  https://api.spotify.com/v1/artists/3LSkCPMcNIb...  3LSkCPMcNIbOscoVhky6ce
# 4  https://api.spotify.com/v1/artists/1y3Ebk2jgtn...  1y3Ebk2jgtnSj9WyWsDhQi
#
#                                               images              name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...         Bad Bunny
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Bad Bunny Zombie
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...          J Balvin
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...    Bad Bunny Trap
# 4                                                 []    Bad Pepa Bunny
#
#    popularity    type                                    uri
# 0         100  artist  spotify:artist:4q3ewBCX7sLwd24euuV69X
# 1           4  artist  spotify:artist:3JAKWLBL9jZ5Ad3KWc04eU
# 2          88  artist  spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5
# 3           0  artist  spotify:artist:3LSkCPMcNIbOscoVhky6ce
# 4           0  artist  spotify:artist:1y3Ebk2jgtnSj9WyWsDhQi

# %% [markdown]
# 1. Ordenamos el df por popularidad
# 2. quedarse con la primera fila
# 3. quedarse con la columna id

# %%
df.sort_values(by='popularity', ascending=False).iloc[0]['id']
# Out:
# '4q3ewBCX7sLwd24euuV69X'

# %% [markdown]
# ### Obteniendo Discografia

# %%
import base64

# %%
def get_token(client_id, client_secret):
    encoded = base64.b64encode(bytes(client_id+':'+client_secret, 'utf-8'))
    params = {'grant_type':'client_credentials'}
    header={'Authorization': 'Basic ' + str(encoded, 'utf-8')}
    r_token= requests.post('https://accounts.spotify.com/api/token', headers=header, data=params)
    if r_token.status_code != 200:
        print('Error en la request.', r_token.json())
        return None
    print('Token válido por {} segundos.'.format(r_token.json()['expires_in']))
    return r_token.json()['access_token']

# %%
client_id='0295d28ca9435c2476bu896aeaa63595843f4'
client_secret= '50ec702sdf5b9142108f73b7159052084cmc5c'
token=get_token(client_id, client_secret)
# Out:
# Token válido por 3600 segundos.

# %%
header={'Authorization':'Bearer {}'.format(token)}

# %%
id_artist
# Out:
# '4q3ewBCX7sLwd24euuV69X'

# %%
r_artist= requests.get(url_artist, headers=header )
r_artist.status_code
# Out:
# 200

# %%
r_artist.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  'followers': {'href': None, 'total': 62921570},
#  'genres': ['reggaeton', 'trap latino', 'urbano latino'],
#  'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#  'id': '4q3ewBCX7sLwd24euuV69X',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb8ee9a6f54dcbd4bc95126b14',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051748ee9a6f54dcbd4bc95126b14',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1788ee9a6f54dcbd4bc95126b14',
#    'width': 160}],
#  'name': 'Bad Bunny',
#  'popularity': 100,
#  'type': 'artist',
#  'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}

# %%
params={'market': 'PY', 'include_groups':'album'}

# %%
url_artist
# Out:
# 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'

# %%
album_artist=requests.get(url_artist+'/albums', headers=header, params=params)
album_artist.status_code
# Out:
# 200

# %%
album_artist.json()
# Out:
# {'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X/albums?offset=0&limit=20&include_groups=album&market=PY',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3RQQmkQEvNCY4prGKE6oc5'},
#    'href': 'https://api.spotify.com/v1/albums/3RQQmkQEvNCY4prGKE6oc5',
#    'id': '3RQQmkQEvNCY4prGKE6oc5',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27349d694203245f241a1bcaa72',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0249d694203245f241a1bcaa72',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485149d694203245f241a1bcaa72',
#      'width': 64}],
#    'name': 'Un Verano Sin Ti',
#    'release_date': '2022-05-06',
#    'release_date_precision': 'day',
#    'total_tracks': 23,
#    'type': 'album',
#    'uri': 'spotify:album:3RQQmkQEvNCY4prGKE6oc5'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2d9BCZeAAhiZWPpbX9aPCW'},
#    'href': 'https://api.spotify.com/v1/albums/2d9BCZeAAhiZWPpbX9aPCW',
#    'id': '2d9BCZeAAhiZWPpbX9aPCW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273005ee342f4eef2cc6e8436ab',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02005ee342f4eef2cc6e8436ab',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851005ee342f4eef2cc6e8436ab',
#      'width': 64}],
#    'name': 'EL ÚLTIMO TOUR DEL MUNDO',
#    'release_date': '2020-11-27',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:2d9BCZeAAhiZWPpbX9aPCW'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4gvQO5mEuhbMSrLIuwXkmz'},
#    'href': 'https://api.spotify.com/v1/albums/4gvQO5mEuhbMSrLIuwXkmz',
#    'id': '4gvQO5mEuhbMSrLIuwXkmz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ae879683217d488c39600092',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ae879683217d488c39600092',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ae879683217d488c39600092',
#      'width': 64}],
#    'name': 'LAS QUE NO IBAN A SALIR',
#    'release_date': '2020-05-10',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:4gvQO5mEuhbMSrLIuwXkmz'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5lJqux7orBlA1QzyiBGti1'},
#    'href': 'https://api.spotify.com/v1/albums/5lJqux7orBlA1QzyiBGti1',
#    'id': '5lJqux7orBlA1QzyiBGti1',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273548f7ec52da7313de0c5e4a0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02548f7ec52da7313de0c5e4a0',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851548f7ec52da7313de0c5e4a0',
#      'width': 64}],
#    'name': 'YHLQMDLG',
#    'release_date': '2020-02-29',
#    'release_date_precision': 'day',
#    'total_tracks': 20,
#    'type': 'album',
#    'uri': 'spotify:album:5lJqux7orBlA1QzyiBGti1'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vyhD5VmyZ7KMfW5gqLgo5'},
#      'href': 'https://api.spotify.com/v1/artists/1vyhD5VmyZ7KMfW5gqLgo5',
#      'id': '1vyhD5VmyZ7KMfW5gqLgo5',
#      'name': 'J Balvin',
#      'type': 'artist',
#      'uri': 'spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6ylFfzx32ICw4L1A7YWNLN'},
#    'href': 'https://api.spotify.com/v1/albums/6ylFfzx32ICw4L1A7YWNLN',
#    'id': '6ylFfzx32ICw4L1A7YWNLN',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734891d9b25d8919448388f3bb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024891d9b25d8919448388f3bb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514891d9b25d8919448388f3bb',
#      'width': 64}],
#    'name': 'OASIS',
#    'release_date': '2019-06-28',
#    'release_date_precision': 'day',
#    'total_tracks': 8,
#    'type': 'album',
#    'uri': 'spotify:album:6ylFfzx32ICw4L1A7YWNLN'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7CjJb2mikwAWA1V6kewFBF'},
#    'href': 'https://api.spotify.com/v1/albums/7CjJb2mikwAWA1V6kewFBF',
#    'id': '7CjJb2mikwAWA1V6kewFBF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732fbd77033247e889cb7d2ac4',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022fbd77033247e889cb7d2ac4',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512fbd77033247e889cb7d2ac4',
#      'width': 64}],
#    'name': 'X 100PRE',
#    'release_date': '2018-12-23',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:7CjJb2mikwAWA1V6kewFBF'}],
#  'limit': 20,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 6}

# %%
album_artist.json()['items'][0]
# Out:
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#    'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#    'id': '4q3ewBCX7sLwd24euuV69X',
#    'name': 'Bad Bunny',
#    'type': 'artist',
#    'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/3RQQmkQEvNCY4prGKE6oc5'},
#  'href': 'https://api.spotify.com/v1/albums/3RQQmkQEvNCY4prGKE6oc5',
#  'id': '3RQQmkQEvNCY4prGKE6oc5',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b27349d694203245f241a1bcaa72',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e0249d694203245f241a1bcaa72',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d0000485149d694203245f241a1bcaa72',
#    'width': 64}],
#  'name': 'Un Verano Sin Ti',
#  'release_date': '2022-05-06',
#  'release_date_precision': 'day',
#  'total_tracks': 23,
#  'type': 'album',
#  'uri': 'spotify:album:3RQQmkQEvNCY4prGKE6oc5'}

# %%
lista_albums = [(album['id'], album['name'],album['release_date']) for album in album_artist.json()['items']]
lista_albums
# Out:
# [('3RQQmkQEvNCY4prGKE6oc5', 'Un Verano Sin Ti', '2022-05-06'),
#  ('2d9BCZeAAhiZWPpbX9aPCW', 'EL ÚLTIMO TOUR DEL MUNDO', '2020-11-27'),
#  ('4gvQO5mEuhbMSrLIuwXkmz', 'LAS QUE NO IBAN A SALIR', '2020-05-10'),
#  ('5lJqux7orBlA1QzyiBGti1', 'YHLQMDLG', '2020-02-29'),
#  ('6ylFfzx32ICw4L1A7YWNLN', 'OASIS', '2019-06-28'),
#  ('7CjJb2mikwAWA1V6kewFBF', 'X 100PRE', '2018-12-23')]

# %%
#seleccionamos el id de un album
id_album_artist='3RQQmkQEvNCY4prGKE6oc5'

# %%
# creamos la ENDPOINT para el album
ep_album='/albums/{id}'.format(id=id_album_artist)

# %%
# creamos la ruta completa del ENDPOINT
url_album_artist=url_base+ep_album
url_album_artist
# Out:
# 'https://api.spotify.com/v1/albums/3RQQmkQEvNCY4prGKE6oc5'

# %%
album_params={'market':'PY'}

# %%
r_album_artist= requests.get(url_album_artist, headers=header, params=album_params)
r_album_artist.json()['tracks']['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 245939,
#   'explicit': True,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6Xom58OOXk2SoU711L2IXO'},
#   'href': 'https://api.spotify.com/v1/tracks/6Xom58OOXk2SoU711L2IXO',
#   'id': '6Xom58OOXk2SoU711L2IXO',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Moscow Mule',
#   'preview_url': 'https://p.scdn.co/mp3-preview/1b0b60e66c2034b95877d2a735a6e5df27548d07?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:6Xom58OOXk2SoU711L2IXO'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 230400,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1dm6z1fWB0cErMszU25dy2'},
#   'href': 'https://api.spotify.com/v1/tracks/1dm6z1fWB0cErMszU25dy2',
#   'id': '1dm6z1fWB0cErMszU25dy2',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Después de la Playa',
#   'preview_url': 'https://p.scdn.co/mp3-preview/5f993fda14dd6f324bb8cf24cf93c7df350209f3?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:1dm6z1fWB0cErMszU25dy2'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/37230BxxYs9ksS7OkZw3IU'},
#     'href': 'https://api.spotify.com/v1/artists/37230BxxYs9ksS7OkZw3IU',
#     'id': '37230BxxYs9ksS7OkZw3IU',
#     'name': 'Chencho Corleone',
#     'type': 'artist',
#     'uri': 'spotify:artist:37230BxxYs9ksS7OkZw3IU'}],
#   'disc_number': 1,
#   'duration_ms': 178567,
#   'explicit': True,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6Sq7ltF9Qa7SNFBsV5Cogx'},
#   'href': 'https://api.spotify.com/v1/tracks/6Sq7ltF9Qa7SNFBsV5Cogx',
#   'id': '6Sq7ltF9Qa7SNFBsV5Cogx',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Me Porto Bonito',
#   'preview_url': 'https://p.scdn.co/mp3-preview/4664314ac1423cd8d6730a9d01640f636ec06bfc?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 243716,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1IHWl5LamUGEuP4ozKQSXZ'},
#   'href': 'https://api.spotify.com/v1/tracks/1IHWl5LamUGEuP4ozKQSXZ',
#   'id': '1IHWl5LamUGEuP4ozKQSXZ',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Tití Me Preguntó',
#   'preview_url': 'https://p.scdn.co/mp3-preview/d69e8b984f636cd292093dc57adf0dabc4ef791c?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:1IHWl5LamUGEuP4ozKQSXZ'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 176936,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5CzixCxDkRXX9mScCmah8O'},
#   'href': 'https://api.spotify.com/v1/tracks/5CzixCxDkRXX9mScCmah8O',
#   'id': '5CzixCxDkRXX9mScCmah8O',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Un Ratito',
#   'preview_url': 'https://p.scdn.co/mp3-preview/fa20c7e9ef3c1d09d662f0bbf1ed9fd7f4c78d43?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:5CzixCxDkRXX9mScCmah8O'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 230704,
#   'explicit': True,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5kVZxyMY1gfdCLiChsfjn1'},
#   'href': 'https://api.spotify.com/v1/tracks/5kVZxyMY1gfdCLiChsfjn1',
#   'id': '5kVZxyMY1gfdCLiChsfjn1',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Yo No Soy Celoso',
#   'preview_url': 'https://p.scdn.co/mp3-preview/5326c8c54a1c34e0b1d6e15dc1eacafdc6b2442a?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:5kVZxyMY1gfdCLiChsfjn1'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6nVcHLIgY5pE2YCl8ubca1'},
#     'href': 'https://api.spotify.com/v1/artists/6nVcHLIgY5pE2YCl8ubca1',
#     'id': '6nVcHLIgY5pE2YCl8ubca1',
#     'name': 'Jhayco',
#     'type': 'artist',
#     'uri': 'spotify:artist:6nVcHLIgY5pE2YCl8ubca1'}],
#   'disc_number': 1,
#   'duration_ms': 237894,
#   'explicit': True,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/41oY4WCTj5kccfesTVFnvN'},
#   'href': 'https://api.spotify.com/v1/tracks/41oY4WCTj5kccfesTVFnvN',
#   'id': '41oY4WCTj5kccfesTVFnvN',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Tarot',
#   'preview_url': 'https://p.scdn.co/mp3-preview/0c0817e45e543b2b9b7ac2e6af3a5dddc11b6cd8?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:41oY4WCTj5kccfesTVFnvN'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 173119,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/31i56LZnwE6uSu3exoHjtB'},
#   'href': 'https://api.spotify.com/v1/tracks/31i56LZnwE6uSu3exoHjtB',
#   'id': '31i56LZnwE6uSu3exoHjtB',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Neverita',
#   'preview_url': 'https://p.scdn.co/mp3-preview/59a710ccbd160b24edbb330a8da60465dbc890de?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:31i56LZnwE6uSu3exoHjtB'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3LKXWvXFWrkwUzJWxzwVpW'},
#     'href': 'https://api.spotify.com/v1/artists/3LKXWvXFWrkwUzJWxzwVpW',
#     'id': '3LKXWvXFWrkwUzJWxzwVpW',
#     'name': 'Tony Dize',
#     'type': 'artist',
#     'uri': 'spotify:artist:3LKXWvXFWrkwUzJWxzwVpW'}],
#   'disc_number': 1,
#   'duration_ms': 198367,
#   'explicit': True,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1797zYiX4cKosMH836X9Gt'},
#   'href': 'https://api.spotify.com/v1/tracks/1797zYiX4cKosMH836X9Gt',
#   'id': '1797zYiX4cKosMH836X9Gt',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'La Corriente',
#   'preview_url': 'https://p.scdn.co/mp3-preview/6660f4e05c9e19e1715de679107d2dbe02332595?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:1797zYiX4cKosMH836X9Gt'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 213061,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5Eax0qFko2dh7Rl2lYs3bx'},
#   'href': 'https://api.spotify.com/v1/tracks/5Eax0qFko2dh7Rl2lYs3bx',
#   'id': '5Eax0qFko2dh7Rl2lYs3bx',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Efecto',
#   'preview_url': 'https://p.scdn.co/mp3-preview/4658112a470b70c3cf7f32472ff81c1144fe5529?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:5Eax0qFko2dh7Rl2lYs3bx'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mcTU81TzQhprhouKaTkpq'},
#     'href': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq',
#     'id': '1mcTU81TzQhprhouKaTkpq',
#     'name': 'Rauw Alejandro',
#     'type': 'artist',
#     'uri': 'spotify:artist:1mcTU81TzQhprhouKaTkpq'}],
#   'disc_number': 1,
#   'duration_ms': 227628,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4tYFy8ALRjIZvnvSLw5lxN'},
#   'href': 'https://api.spotify.com/v1/tracks/4tYFy8ALRjIZvnvSLw5lxN',
#   'id': '4tYFy8ALRjIZvnvSLw5lxN',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Party',
#   'preview_url': 'https://p.scdn.co/mp3-preview/cdba247b040b191e2006ec9bd33c9b074f0e6818?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 11,
#   'type': 'track',
#   'uri': 'spotify:track:4tYFy8ALRjIZvnvSLw5lxN'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 210989,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2uflssWlCaJ6CbTMOsUpNI'},
#   'href': 'https://api.spotify.com/v1/tracks/2uflssWlCaJ6CbTMOsUpNI',
#   'id': '2uflssWlCaJ6CbTMOsUpNI',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Aguacero',
#   'preview_url': 'https://p.scdn.co/mp3-preview/0fac42ce68f0567c1c00ac053b279450db89f6bc?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 12,
#   'type': 'track',
#   'uri': 'spotify:track:2uflssWlCaJ6CbTMOsUpNI'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 176000,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2NMjggapJcXXM7WccGEBUO'},
#   'href': 'https://api.spotify.com/v1/tracks/2NMjggapJcXXM7WccGEBUO',
#   'id': '2NMjggapJcXXM7WccGEBUO',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Enséñame a Bailar',
#   'preview_url': 'https://p.scdn.co/mp3-preview/7d1f78d5b5aa00a0eb3eeb2ca5cac410d003ab7d?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:2NMjggapJcXXM7WccGEBUO'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5n9bMYfz9qss2VOW89EVs2'},
#     'href': 'https://api.spotify.com/v1/artists/5n9bMYfz9qss2VOW89EVs2',
#     'id': '5n9bMYfz9qss2VOW89EVs2',
#     'name': 'Bomba Estéreo',
#     'type': 'artist',
#     'uri': 'spotify:artist:5n9bMYfz9qss2VOW89EVs2'}],
#   'disc_number': 1,
#   'duration_ms': 258298,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3k3NWokhRRkEPhCzPmV8TW'},
#   'href': 'https://api.spotify.com/v1/tracks/3k3NWokhRRkEPhCzPmV8TW',
#   'id': '3k3NWokhRRkEPhCzPmV8TW',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Ojitos Lindos',
#   'preview_url': 'https://p.scdn.co/mp3-preview/db4bfe899bfe93f98077d6f73f15c06b8bd5e6fa?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 14,
#   'type': 'track',
#   'uri': 'spotify:track:3k3NWokhRRkEPhCzPmV8TW'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 208615,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4d4ZXH4dr5bYfgErHiZCX2'},
#   'href': 'https://api.spotify.com/v1/tracks/4d4ZXH4dr5bYfgErHiZCX2',
#   'id': '4d4ZXH4dr5bYfgErHiZCX2',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Dos Mil 16',
#   'preview_url': 'https://p.scdn.co/mp3-preview/56ae97d5d3f7ae04254fa9897c620d0f27a3cc13?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 15,
#   'type': 'track',
#   'uri': 'spotify:track:4d4ZXH4dr5bYfgErHiZCX2'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 201816,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0UvZcEfpzVyx47QsRbjyBz'},
#   'href': 'https://api.spotify.com/v1/tracks/0UvZcEfpzVyx47QsRbjyBz',
#   'id': '0UvZcEfpzVyx47QsRbjyBz',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'El Apagón',
#   'preview_url': 'https://p.scdn.co/mp3-preview/5ac9c80b65049548307dae9cf9404447b62f5c4e?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 16,
#   'type': 'track',
#   'uri': 'spotify:track:0UvZcEfpzVyx47QsRbjyBz'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2sSGPbdZJkaSE2AbcGOACx'},
#     'href': 'https://api.spotify.com/v1/artists/2sSGPbdZJkaSE2AbcGOACx',
#     'id': '2sSGPbdZJkaSE2AbcGOACx',
#     'name': 'The Marías',
#     'type': 'artist',
#     'uri': 'spotify:artist:2sSGPbdZJkaSE2AbcGOACx'}],
#   'disc_number': 1,
#   'duration_ms': 244444,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0E0DRHf5PfMeor0ZCwB3oT'},
#   'href': 'https://api.spotify.com/v1/tracks/0E0DRHf5PfMeor0ZCwB3oT',
#   'id': '0E0DRHf5PfMeor0ZCwB3oT',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Otro Atardecer',
#   'preview_url': 'https://p.scdn.co/mp3-preview/14a76318939ece431eea7e10bca6243019a5f30e?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 17,
#   'type': 'track',
#   'uri': 'spotify:track:0E0DRHf5PfMeor0ZCwB3oT'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 196412,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6VrQTLzzuyGIYjUDe4kAZk'},
#   'href': 'https://api.spotify.com/v1/tracks/6VrQTLzzuyGIYjUDe4kAZk',
#   'id': '6VrQTLzzuyGIYjUDe4kAZk',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Un Coco',
#   'preview_url': 'https://p.scdn.co/mp3-preview/0a5238a2b401d3f430dd2e9c732c01163bbac874?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 18,
#   'type': 'track',
#   'uri': 'spotify:track:6VrQTLzzuyGIYjUDe4kAZk'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0MoaBi6dSquXp6rrlqlF8R'},
#     'href': 'https://api.spotify.com/v1/artists/0MoaBi6dSquXp6rrlqlF8R',
#     'id': '0MoaBi6dSquXp6rrlqlF8R',
#     'name': 'Buscabulla',
#     'type': 'artist',
#     'uri': 'spotify:artist:0MoaBi6dSquXp6rrlqlF8R'}],
#   'disc_number': 1,
#   'duration_ms': 339611,
#   'explicit': True,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/44XjoNvtwevktFKjvVe1vH'},
#   'href': 'https://api.spotify.com/v1/tracks/44XjoNvtwevktFKjvVe1vH',
#   'id': '44XjoNvtwevktFKjvVe1vH',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Andrea',
#   'preview_url': 'https://p.scdn.co/mp3-preview/4406a4e4a6db18442f5404e5da696670f7e35299?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 19,
#   'type': 'track',
#   'uri': 'spotify:track:44XjoNvtwevktFKjvVe1vH'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 180929,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/28GCbKgjlVD9eDmasGbe0T'},
#   'href': 'https://api.spotify.com/v1/tracks/28GCbKgjlVD9eDmasGbe0T',
#   'id': '28GCbKgjlVD9eDmasGbe0T',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Me Fui de Vacaciones',
#   'preview_url': 'https://p.scdn.co/mp3-preview/b84db45aec8b2aeeb09db3882cb4196f3e46454b?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 20,
#   'type': 'track',
#   'uri': 'spotify:track:28GCbKgjlVD9eDmasGbe0T'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 148143,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/18HOjcvTVV7W8YzBuOsAPS'},
#   'href': 'https://api.spotify.com/v1/tracks/18HOjcvTVV7W8YzBuOsAPS',
#   'id': '18HOjcvTVV7W8YzBuOsAPS',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Un Verano Sin Ti',
#   'preview_url': 'https://p.scdn.co/mp3-preview/3b1df9d49524fe377232587c294a312d8886018a?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 21,
#   'type': 'track',
#   'uri': 'spotify:track:18HOjcvTVV7W8YzBuOsAPS'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'disc_number': 1,
#   'duration_ms': 139041,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0wihfILRNOwE2156Shezc8'},
#   'href': 'https://api.spotify.com/v1/tracks/0wihfILRNOwE2156Shezc8',
#   'id': '0wihfILRNOwE2156Shezc8',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Agosto',
#   'preview_url': 'https://p.scdn.co/mp3-preview/52b893942a6b5ea7a15ba5261a4bc689e1316157?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 22,
#   'type': 'track',
#   'uri': 'spotify:track:0wihfILRNOwE2156Shezc8'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0GM7qgcRCORpGnfcN2tCiB'},
#     'href': 'https://api.spotify.com/v1/artists/0GM7qgcRCORpGnfcN2tCiB',
#     'id': '0GM7qgcRCORpGnfcN2tCiB',
#     'name': 'Tainy',
#     'type': 'artist',
#     'uri': 'spotify:artist:0GM7qgcRCORpGnfcN2tCiB'}],
#   'disc_number': 1,
#   'duration_ms': 250533,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/71wFwRo8xGc4lrcyKwsvba'},
#   'href': 'https://api.spotify.com/v1/tracks/71wFwRo8xGc4lrcyKwsvba',
#   'id': '71wFwRo8xGc4lrcyKwsvba',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Callaita',
#   'preview_url': 'https://p.scdn.co/mp3-preview/8b992c5f1935924a772526b615aa7b76ce3e112f?cid=0295289435c2476b96aeaa63595843f4',
#   'track_number': 23,
#   'type': 'track',
#   'uri': 'spotify:track:71wFwRo8xGc4lrcyKwsvba'}]

# %%
info_album=[(track['id'], track['name']) for track in r_album_artist.json()['tracks']['items']]
info_album
# Out:
# [('6Xom58OOXk2SoU711L2IXO', 'Moscow Mule'),
#  ('1dm6z1fWB0cErMszU25dy2', 'Después de la Playa'),
#  ('6Sq7ltF9Qa7SNFBsV5Cogx', 'Me Porto Bonito'),
#  ('1IHWl5LamUGEuP4ozKQSXZ', 'Tití Me Preguntó'),
#  ('5CzixCxDkRXX9mScCmah8O', 'Un Ratito'),
#  ('5kVZxyMY1gfdCLiChsfjn1', 'Yo No Soy Celoso'),
#  ('41oY4WCTj5kccfesTVFnvN', 'Tarot'),
#  ('31i56LZnwE6uSu3exoHjtB', 'Neverita'),
#  ('1797zYiX4cKosMH836X9Gt', 'La Corriente'),
#  ('5Eax0qFko2dh7Rl2lYs3bx', 'Efecto'),
#  ('4tYFy8ALRjIZvnvSLw5lxN', 'Party'),
#  ('2uflssWlCaJ6CbTMOsUpNI', 'Aguacero'),
#  ('2NMjggapJcXXM7WccGEBUO', 'Enséñame a Bailar'),
#  ('3k3NWokhRRkEPhCzPmV8TW', 'Ojitos Lindos'),
#  ('4d4ZXH4dr5bYfgErHiZCX2', 'Dos Mil 16'),
#  ('0UvZcEfpzVyx47QsRbjyBz', 'El Apagón'),
#  ('0E0DRHf5PfMeor0ZCwB3oT', 'Otro Atardecer'),
#  ('6VrQTLzzuyGIYjUDe4kAZk', 'Un Coco'),
#  ('44XjoNvtwevktFKjvVe1vH', 'Andrea'),
#  ('28GCbKgjlVD9eDmasGbe0T', 'Me Fui de Vacaciones'),
#  ('18HOjcvTVV7W8YzBuOsAPS', 'Un Verano Sin Ti'),
#  ('0wihfILRNOwE2156Shezc8', 'Agosto'),
#  ('71wFwRo8xGc4lrcyKwsvba', 'Callaita')]

# %%
def obtener_discrografia(artist_id, token, return_name= False, page_limit=50, market=None):
    #tenemos la url del ENDPOINT para hacer peticiones de albumes en funcion del id del artista
    url=f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    #cabecera donde pasaremos el tokens
    header = {'Authorization':f'Bearer {token}'}
    #parametros en la que se basa la peticion
    params={'limit':page_limit, 'offset':0, 'market':market,'include_groups':'album' }
    lista_album=[]
    #hacemos una solicitud inicial con los paramatro y la cabecera
    r=requests.get(url, params=params, headers=header)

    if r.status_code != 200:
        #verificamos si el status_code tiene error, imprimimos el json
        print('Error en la request.', r.json())
        return None #retornamos None, por que no pudimos devolver nada
    
    #seteamos el parametro return_name si es true
    if return_name:
        # para que item de la request, vamos a guardar en nuestra lista el id y name
        lista_album+=[(item['id'],item['name']) for item in r.json()['items']]
    else:
        # para la opcion por defecto de nuestra funcion
        lista_album+=[(item['id']) for item in r.json()['items']]
    
    #debemos hacer la peticion de items hasta el final de nuestras paginas del json
    while r.json()['next']:
        r=requests.get(r.json()['next'], headers=header)# El resto de los parámetros están dentro de la URL ->next
        
        if r.status_code != 200:
        #verificamos si el status_code tiene error, imprimimos el json
            print('Error en la request.', r.json())
            return None #retornamos None, por que no pudimos devolver nada
        
        if return_name:
            # para que item de la request, vamos a guardar en nuestra lista el id y name
            lista_album+=[(item['id'],item['name']) for item in r.json()['items']]
        else:
            # para la opcion por defecto de nuestra funcion
            lista_album+=[(item['id']) for item in r.json()['items']]
    
    # ahora si podemos retornar la lista de items, que son las discografias
    return lista_album

# %%
print (obtener_discrografia(id_artist, token, return_name=True))
# Out:
# [('3RQQmkQEvNCY4prGKE6oc5', 'Un Verano Sin Ti'), ('2d9BCZeAAhiZWPpbX9aPCW', 'EL ÚLTIMO TOUR DEL MUNDO'), ('4gvQO5mEuhbMSrLIuwXkmz', 'LAS QUE NO IBAN A SALIR'), ('5lJqux7orBlA1QzyiBGti1', 'YHLQMDLG'), ('6ylFfzx32ICw4L1A7YWNLN', 'OASIS'), ('7CjJb2mikwAWA1V6kewFBF', 'X 100PRE')]

# %%
def obtener_tracks(album_id, token, return_name=False, page_limit=50, market=None):
    url=f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    header = {'Authorization': f'Bearer {token}'}
    params = {'limit': page_limit, 
              'offset': 0,
              'market': market}
    lista_tracks = []
    r = requests.get(url, params=params, headers=header)
    
    if r.status_code != 200:
        print('Error en request.', r.json())
        return None
    
    if return_name:
        lista_tracks += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista_tracks += [item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header) # El resto de los parámetros están dentro de la URL
        if return_name:
            lista_tracks += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista_tracks += [item['id'] for item in r.json()['items']]
    
    return lista_tracks

# %%
print (obtener_tracks(id_album_artist, token, True))
# Out:
# [('6Xom58OOXk2SoU711L2IXO', 'Moscow Mule'), ('1dm6z1fWB0cErMszU25dy2', 'Después de la Playa'), ('6Sq7ltF9Qa7SNFBsV5Cogx', 'Me Porto Bonito'), ('1IHWl5LamUGEuP4ozKQSXZ', 'Tití Me Preguntó'), ('5CzixCxDkRXX9mScCmah8O', 'Un Ratito'), ('5kVZxyMY1gfdCLiChsfjn1', 'Yo No Soy Celoso'), ('41oY4WCTj5kccfesTVFnvN', 'Tarot'), ('31i56LZnwE6uSu3exoHjtB', 'Neverita'), ('1797zYiX4cKosMH836X9Gt', 'La Corriente'), ('5Eax0qFko2dh7Rl2lYs3bx', 'Efecto'), ('4tYFy8ALRjIZvnvSLw5lxN', 'Party'), ('2uflssWlCaJ6CbTMOsUpNI', 'Aguacero'), ('2NMjggapJcXXM7WccGEBUO', 'Enséñame a Bailar'), ('3k3NWokhRRkEPhCzPmV8TW', 'Ojitos Lindos'), ('4d4ZXH4dr5bYfgErHiZCX2', 'Dos Mil 16'), ('0UvZcEfpzVyx47QsRbjyBz', 'El Apagón'), ('0E0DRHf5PfMeor0ZCwB3oT', 'Otro Atardecer'), ('6VrQTLzzuyGIYjUDe4kAZk', 'Un Coco'), ('44XjoNvtwevktFKjvVe1vH', 'Andrea'), ('28GCbKgjlVD9eDmasGbe0T', 'Me Fui de Vacaciones'), ('18HOjcvTVV7W8YzBuOsAPS', 'Un Verano Sin Ti'), ('0wihfILRNOwE2156Shezc8', 'Agosto'), ('71wFwRo8xGc4lrcyKwsvba', 'Callaita')]

# %% [markdown]
# Utilizando estas funciones podemos obtener todos las canciones que tiene un artista publicadas en Spotify

# %%
for album in obtener_discrografia(id_artist, token, return_name=True, market='PY'):
    #vamos a imprimir el nombre de cada Album 
    print(album[1])
    #como sabemos que la primera posicion de nuestra lista de album es el id del album, 
    #enviamos como parametro ese ID, para buscar sus tracks
    for track in obtener_tracks(album[0], token, return_name=True, market='PY'):
        # imprimimos los tracks de cada album
        print('\t', track[1])
# Out:
# Un Verano Sin Ti
# 	 Moscow Mule
# 	 Después de la Playa
# 	 Me Porto Bonito
# 	 Tití Me Preguntó
# 	 Un Ratito
# 	 Yo No Soy Celoso
# 	 Tarot
# 	 Neverita
# 	 La Corriente
# 	 Efecto
# 	 Party
# 	 Aguacero
# 	 Enséñame a Bailar
# 	 Ojitos Lindos
# 	 Dos Mil 16
# 	 El Apagón
# 	 Otro Atardecer
# 	 Un Coco
# 	 Andrea
# 	 Me Fui de Vacaciones
# 	 Un Verano Sin Ti
# 	 Agosto
# 	 Callaita
# EL ÚLTIMO TOUR DEL MUNDO
# 	 EL MUNDO ES MÍO
# 	 TE MUDASTE
# 	 HOY COBRÉ
# 	 MALDITA POBREZA
# 	 LA NOCHE DE ANOCHE
# 	 TE DESEO LO MEJOR
# 	 YO VISTO ASÍ
# 	 HACIENDO QUE ME AMAS
# 	 BOOKER T
# 	 LA DROGA
# 	 DÁKITI
# 	 TRELLAS
# 	 SORRY PAPI
# 	 120
# 	 ANTES QUE SE ACABE
# 	 CANTARES DE NAVIDAD
# LAS QUE NO IBAN A SALIR
# 	 SI ELLA SALE
# 	 MÁS DE UNA CITA
# 	 BYE ME FUI
# 	 CANCIÓN CON YANDEL
# 	 PA' ROMPERLA
# 	 BAD CON NICKY
# 	 BENDICIONES
# 	 CÓMO SE SIENTE - Remix
# 	 RONCA FREESTYLE
# 	 EN CASITA
# YHLQMDLG
# 	 Si Veo a Tu Mamá
# 	 La Difícil
# 	 Pero Ya No
# 	 La Santa
# 	 Yo Perreo Sola
# 	 Bichiyal
# 	 Soliá
# 	 La Zona
# 	 Que Malo
# 	 Vete
# 	 Ignorantes
# 	 A Tu Merced
# 	 Una Vez
# 	 Safaera
# 	 25/8
# 	 Está Cabrón Ser Yo
# 	 Puesto Pa' Guerrial
# 	 P FKN R
# 	 Hablamos Mañana
# 	 <3
# OASIS
# 	 MOJAITA
# 	 YO LE LLEGO
# 	 CUIDAO POR AHÍ
# 	 QUE PRETENDES
# 	 LA CANCIÓN
# 	 UN PESO
# 	 ODIO
# 	 COMO UN BEBÉ
# X 100PRE
# 	 NI BIEN NI MAL
# 	 200 Mph
# 	 ¿Quien Tu Eres?
# 	 Caro
# 	 Tenemos Que Hablar
# 	 Otra Noche en Miami
# 	 Ser Bichote
# 	 Si Estuviésemos Juntos
# 	 Solo de Mi
# 	 Cuando Perriabas
# 	 La Romana
# 	 Como Antes
# 	 RLNDT
# 	 Estamos Bien
# 	 MIA

# %%
r_album_artist.json()
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#    'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#    'id': '4q3ewBCX7sLwd24euuV69X',
#    'name': 'Bad Bunny',
#    'type': 'artist',
#    'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#  'copyrights': [{'text': '(C) 2022 Rimas Entertainment', 'type': 'C'},
#   {'text': '(P) 2022 Rimas Entertainment', 'type': 'P'}],
#  'external_ids': {'upc': '196626945068'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/3RQQmkQEvNCY4prGKE6oc5'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/3RQQmkQEvNCY4prGKE6oc5',
#  'id': '3RQQmkQEvNCY4prGKE6oc5',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b27349d694203245f241a1bcaa72',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e0249d694203245f241a1bcaa72',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d0000485149d694203245f241a1bcaa72',
#    'width': 64}],
#  'label': 'Rimas Entertainment LLC',
#  'name': 'Un Verano Sin Ti',
#  'popularity': 100,
#  'release_date': '2022-05-06',
#  'release_date_precision': 'day',
#  'total_tracks': 23,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/3RQQmkQEvNCY4prGKE6oc5/tracks?offset=0&limit=50&market=PY',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 245939,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Xom58OOXk2SoU711L2IXO'},
#     'href': 'https://api.spotify.com/v1/tracks/6Xom58OOXk2SoU711L2IXO',
#     'id': '6Xom58OOXk2SoU711L2IXO',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Moscow Mule',
#     'preview_url': 'https://p.scdn.co/mp3-preview/1b0b60e66c2034b95877d2a735a6e5df27548d07?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6Xom58OOXk2SoU711L2IXO'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 230400,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1dm6z1fWB0cErMszU25dy2'},
#     'href': 'https://api.spotify.com/v1/tracks/1dm6z1fWB0cErMszU25dy2',
#     'id': '1dm6z1fWB0cErMszU25dy2',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Después de la Playa',
#     'preview_url': 'https://p.scdn.co/mp3-preview/5f993fda14dd6f324bb8cf24cf93c7df350209f3?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1dm6z1fWB0cErMszU25dy2'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/37230BxxYs9ksS7OkZw3IU'},
#       'href': 'https://api.spotify.com/v1/artists/37230BxxYs9ksS7OkZw3IU',
#       'id': '37230BxxYs9ksS7OkZw3IU',
#       'name': 'Chencho Corleone',
#       'type': 'artist',
#       'uri': 'spotify:artist:37230BxxYs9ksS7OkZw3IU'}],
#     'disc_number': 1,
#     'duration_ms': 178567,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Sq7ltF9Qa7SNFBsV5Cogx'},
#     'href': 'https://api.spotify.com/v1/tracks/6Sq7ltF9Qa7SNFBsV5Cogx',
#     'id': '6Sq7ltF9Qa7SNFBsV5Cogx',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Me Porto Bonito',
#     'preview_url': 'https://p.scdn.co/mp3-preview/4664314ac1423cd8d6730a9d01640f636ec06bfc?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 243716,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1IHWl5LamUGEuP4ozKQSXZ'},
#     'href': 'https://api.spotify.com/v1/tracks/1IHWl5LamUGEuP4ozKQSXZ',
#     'id': '1IHWl5LamUGEuP4ozKQSXZ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Tití Me Preguntó',
#     'preview_url': 'https://p.scdn.co/mp3-preview/d69e8b984f636cd292093dc57adf0dabc4ef791c?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1IHWl5LamUGEuP4ozKQSXZ'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 176936,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5CzixCxDkRXX9mScCmah8O'},
#     'href': 'https://api.spotify.com/v1/tracks/5CzixCxDkRXX9mScCmah8O',
#     'id': '5CzixCxDkRXX9mScCmah8O',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Un Ratito',
#     'preview_url': 'https://p.scdn.co/mp3-preview/fa20c7e9ef3c1d09d662f0bbf1ed9fd7f4c78d43?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5CzixCxDkRXX9mScCmah8O'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 230704,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5kVZxyMY1gfdCLiChsfjn1'},
#     'href': 'https://api.spotify.com/v1/tracks/5kVZxyMY1gfdCLiChsfjn1',
#     'id': '5kVZxyMY1gfdCLiChsfjn1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Yo No Soy Celoso',
#     'preview_url': 'https://p.scdn.co/mp3-preview/5326c8c54a1c34e0b1d6e15dc1eacafdc6b2442a?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5kVZxyMY1gfdCLiChsfjn1'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6nVcHLIgY5pE2YCl8ubca1'},
#       'href': 'https://api.spotify.com/v1/artists/6nVcHLIgY5pE2YCl8ubca1',
#       'id': '6nVcHLIgY5pE2YCl8ubca1',
#       'name': 'Jhayco',
#       'type': 'artist',
#       'uri': 'spotify:artist:6nVcHLIgY5pE2YCl8ubca1'}],
#     'disc_number': 1,
#     'duration_ms': 237894,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/41oY4WCTj5kccfesTVFnvN'},
#     'href': 'https://api.spotify.com/v1/tracks/41oY4WCTj5kccfesTVFnvN',
#     'id': '41oY4WCTj5kccfesTVFnvN',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Tarot',
#     'preview_url': 'https://p.scdn.co/mp3-preview/0c0817e45e543b2b9b7ac2e6af3a5dddc11b6cd8?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:41oY4WCTj5kccfesTVFnvN'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 173119,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/31i56LZnwE6uSu3exoHjtB'},
#     'href': 'https://api.spotify.com/v1/tracks/31i56LZnwE6uSu3exoHjtB',
#     'id': '31i56LZnwE6uSu3exoHjtB',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Neverita',
#     'preview_url': 'https://p.scdn.co/mp3-preview/59a710ccbd160b24edbb330a8da60465dbc890de?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:31i56LZnwE6uSu3exoHjtB'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3LKXWvXFWrkwUzJWxzwVpW'},
#       'href': 'https://api.spotify.com/v1/artists/3LKXWvXFWrkwUzJWxzwVpW',
#       'id': '3LKXWvXFWrkwUzJWxzwVpW',
#       'name': 'Tony Dize',
#       'type': 'artist',
#       'uri': 'spotify:artist:3LKXWvXFWrkwUzJWxzwVpW'}],
#     'disc_number': 1,
#     'duration_ms': 198367,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1797zYiX4cKosMH836X9Gt'},
#     'href': 'https://api.spotify.com/v1/tracks/1797zYiX4cKosMH836X9Gt',
#     'id': '1797zYiX4cKosMH836X9Gt',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'La Corriente',
#     'preview_url': 'https://p.scdn.co/mp3-preview/6660f4e05c9e19e1715de679107d2dbe02332595?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:1797zYiX4cKosMH836X9Gt'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 213061,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Eax0qFko2dh7Rl2lYs3bx'},
#     'href': 'https://api.spotify.com/v1/tracks/5Eax0qFko2dh7Rl2lYs3bx',
#     'id': '5Eax0qFko2dh7Rl2lYs3bx',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Efecto',
#     'preview_url': 'https://p.scdn.co/mp3-preview/4658112a470b70c3cf7f32472ff81c1144fe5529?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:5Eax0qFko2dh7Rl2lYs3bx'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mcTU81TzQhprhouKaTkpq'},
#       'href': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq',
#       'id': '1mcTU81TzQhprhouKaTkpq',
#       'name': 'Rauw Alejandro',
#       'type': 'artist',
#       'uri': 'spotify:artist:1mcTU81TzQhprhouKaTkpq'}],
#     'disc_number': 1,
#     'duration_ms': 227628,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4tYFy8ALRjIZvnvSLw5lxN'},
#     'href': 'https://api.spotify.com/v1/tracks/4tYFy8ALRjIZvnvSLw5lxN',
#     'id': '4tYFy8ALRjIZvnvSLw5lxN',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Party',
#     'preview_url': 'https://p.scdn.co/mp3-preview/cdba247b040b191e2006ec9bd33c9b074f0e6818?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:4tYFy8ALRjIZvnvSLw5lxN'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 210989,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2uflssWlCaJ6CbTMOsUpNI'},
#     'href': 'https://api.spotify.com/v1/tracks/2uflssWlCaJ6CbTMOsUpNI',
#     'id': '2uflssWlCaJ6CbTMOsUpNI',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Aguacero',
#     'preview_url': 'https://p.scdn.co/mp3-preview/0fac42ce68f0567c1c00ac053b279450db89f6bc?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:2uflssWlCaJ6CbTMOsUpNI'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 176000,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2NMjggapJcXXM7WccGEBUO'},
#     'href': 'https://api.spotify.com/v1/tracks/2NMjggapJcXXM7WccGEBUO',
#     'id': '2NMjggapJcXXM7WccGEBUO',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Enséñame a Bailar',
#     'preview_url': 'https://p.scdn.co/mp3-preview/7d1f78d5b5aa00a0eb3eeb2ca5cac410d003ab7d?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:2NMjggapJcXXM7WccGEBUO'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5n9bMYfz9qss2VOW89EVs2'},
#       'href': 'https://api.spotify.com/v1/artists/5n9bMYfz9qss2VOW89EVs2',
#       'id': '5n9bMYfz9qss2VOW89EVs2',
#       'name': 'Bomba Estéreo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5n9bMYfz9qss2VOW89EVs2'}],
#     'disc_number': 1,
#     'duration_ms': 258298,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3k3NWokhRRkEPhCzPmV8TW'},
#     'href': 'https://api.spotify.com/v1/tracks/3k3NWokhRRkEPhCzPmV8TW',
#     'id': '3k3NWokhRRkEPhCzPmV8TW',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Ojitos Lindos',
#     'preview_url': 'https://p.scdn.co/mp3-preview/db4bfe899bfe93f98077d6f73f15c06b8bd5e6fa?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:3k3NWokhRRkEPhCzPmV8TW'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 208615,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4d4ZXH4dr5bYfgErHiZCX2'},
#     'href': 'https://api.spotify.com/v1/tracks/4d4ZXH4dr5bYfgErHiZCX2',
#     'id': '4d4ZXH4dr5bYfgErHiZCX2',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Dos Mil 16',
#     'preview_url': 'https://p.scdn.co/mp3-preview/56ae97d5d3f7ae04254fa9897c620d0f27a3cc13?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:4d4ZXH4dr5bYfgErHiZCX2'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 201816,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0UvZcEfpzVyx47QsRbjyBz'},
#     'href': 'https://api.spotify.com/v1/tracks/0UvZcEfpzVyx47QsRbjyBz',
#     'id': '0UvZcEfpzVyx47QsRbjyBz',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'El Apagón',
#     'preview_url': 'https://p.scdn.co/mp3-preview/5ac9c80b65049548307dae9cf9404447b62f5c4e?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:0UvZcEfpzVyx47QsRbjyBz'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2sSGPbdZJkaSE2AbcGOACx'},
#       'href': 'https://api.spotify.com/v1/artists/2sSGPbdZJkaSE2AbcGOACx',
#       'id': '2sSGPbdZJkaSE2AbcGOACx',
#       'name': 'The Marías',
#       'type': 'artist',
#       'uri': 'spotify:artist:2sSGPbdZJkaSE2AbcGOACx'}],
#     'disc_number': 1,
#     'duration_ms': 244444,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0E0DRHf5PfMeor0ZCwB3oT'},
#     'href': 'https://api.spotify.com/v1/tracks/0E0DRHf5PfMeor0ZCwB3oT',
#     'id': '0E0DRHf5PfMeor0ZCwB3oT',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Otro Atardecer',
#     'preview_url': 'https://p.scdn.co/mp3-preview/14a76318939ece431eea7e10bca6243019a5f30e?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:0E0DRHf5PfMeor0ZCwB3oT'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 196412,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6VrQTLzzuyGIYjUDe4kAZk'},
#     'href': 'https://api.spotify.com/v1/tracks/6VrQTLzzuyGIYjUDe4kAZk',
#     'id': '6VrQTLzzuyGIYjUDe4kAZk',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Un Coco',
#     'preview_url': 'https://p.scdn.co/mp3-preview/0a5238a2b401d3f430dd2e9c732c01163bbac874?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:6VrQTLzzuyGIYjUDe4kAZk'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0MoaBi6dSquXp6rrlqlF8R'},
#       'href': 'https://api.spotify.com/v1/artists/0MoaBi6dSquXp6rrlqlF8R',
#       'id': '0MoaBi6dSquXp6rrlqlF8R',
#       'name': 'Buscabulla',
#       'type': 'artist',
#       'uri': 'spotify:artist:0MoaBi6dSquXp6rrlqlF8R'}],
#     'disc_number': 1,
#     'duration_ms': 339611,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/44XjoNvtwevktFKjvVe1vH'},
#     'href': 'https://api.spotify.com/v1/tracks/44XjoNvtwevktFKjvVe1vH',
#     'id': '44XjoNvtwevktFKjvVe1vH',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Andrea',
#     'preview_url': 'https://p.scdn.co/mp3-preview/4406a4e4a6db18442f5404e5da696670f7e35299?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:44XjoNvtwevktFKjvVe1vH'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 180929,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/28GCbKgjlVD9eDmasGbe0T'},
#     'href': 'https://api.spotify.com/v1/tracks/28GCbKgjlVD9eDmasGbe0T',
#     'id': '28GCbKgjlVD9eDmasGbe0T',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Me Fui de Vacaciones',
#     'preview_url': 'https://p.scdn.co/mp3-preview/b84db45aec8b2aeeb09db3882cb4196f3e46454b?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:28GCbKgjlVD9eDmasGbe0T'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 148143,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/18HOjcvTVV7W8YzBuOsAPS'},
#     'href': 'https://api.spotify.com/v1/tracks/18HOjcvTVV7W8YzBuOsAPS',
#     'id': '18HOjcvTVV7W8YzBuOsAPS',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Un Verano Sin Ti',
#     'preview_url': 'https://p.scdn.co/mp3-preview/3b1df9d49524fe377232587c294a312d8886018a?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 21,
#     'type': 'track',
#     'uri': 'spotify:track:18HOjcvTVV7W8YzBuOsAPS'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 139041,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0wihfILRNOwE2156Shezc8'},
#     'href': 'https://api.spotify.com/v1/tracks/0wihfILRNOwE2156Shezc8',
#     'id': '0wihfILRNOwE2156Shezc8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Agosto',
#     'preview_url': 'https://p.scdn.co/mp3-preview/52b893942a6b5ea7a15ba5261a4bc689e1316157?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 22,
#     'type': 'track',
#     'uri': 'spotify:track:0wihfILRNOwE2156Shezc8'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0GM7qgcRCORpGnfcN2tCiB'},
#       'href': 'https://api.spotify.com/v1/artists/0GM7qgcRCORpGnfcN2tCiB',
#       'id': '0GM7qgcRCORpGnfcN2tCiB',
#       'name': 'Tainy',
#       'type': 'artist',
#       'uri': 'spotify:artist:0GM7qgcRCORpGnfcN2tCiB'}],
#     'disc_number': 1,
#     'duration_ms': 250533,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/71wFwRo8xGc4lrcyKwsvba'},
#     'href': 'https://api.spotify.com/v1/tracks/71wFwRo8xGc4lrcyKwsvba',
#     'id': '71wFwRo8xGc4lrcyKwsvba',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Callaita',
#     'preview_url': 'https://p.scdn.co/mp3-preview/8b992c5f1935924a772526b615aa7b76ce3e112f?cid=0295289435c2476b96aeaa63595843f4',
#     'track_number': 23,
#     'type': 'track',
#     'uri': 'spotify:track:71wFwRo8xGc4lrcyKwsvba'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 23},
#  'type': 'album',
#  'uri': 'spotify:album:3RQQmkQEvNCY4prGKE6oc5'}

# %%
# ahora obtengamos el preview de una musica
preview_url=r_album_artist.json()['tracks']['items'][1]['preview_url']

# %%
# hacemos una peticion get y vemos su estado
preview = requests.get(preview_url)
preview.status_code
# Out:
# 200

# %%
#podemos ver su contenido en bytes
preview.content
# Out:
# b'ID3\x04\x00\x00\x00\x00\x13?GEOB\x00\x00\x08M\x00\x00\x00application/json\x00metadata.json\x00\x00{"start_time": 68.19797199085487, "loop_duration": 25.14394, "crossfade_duration": 0.1915880091451343, "beats": [0.19158800914513563, 0.9919480091451334, 1.796008009145126, 2.60126800914513, 3.3962280091451333, 4.188548009145137, 4.970308009145128, 5.748198009145128, 6.532928009145138, 7.319048009145135, 8.10744800914513, 8.894908009145126, 9.68613800914514, 10.481338009145134, 11.283508009145137, 12.077758009145128, 12.871568009145136, 13.662238009145128, 14.451618009145136, 15.238408009145132, 16.01967800914514, 16.793758009145137, 17.569248009145127, 18.34217800914513, 19.115678009145128, 19.892028009145136, 20.667788009145127, 21.445248009145132, 22.224708009145132, 23.000388009145126, 23.778348009145134, 24.557608009145127, 25.335528009145136, 26.114138009145137, 26.892748009145137, 27.67209800914513, 28.45088800914513, 29.227098009145138], "downbeats": [0.19158800914513563, 3.3962280091451333, 6.532928009145138, 9.68613800914514, 12.871568009145136, 16.01967800914514, 19.115678009145128, 22.224708009145132, 25.335528009145136, 28.45088800914513]} ...

# %%
#Importamos la libreria de python para poder previsualizar
import IPython.display as ipd

# %%
# y utilizamos el metodo de audio de nuestra libreria
ipd.Audio(preview.content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
